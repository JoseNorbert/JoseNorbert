# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseNorbert/JoseNorbert/blob/main/multiindex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from IPython.utils import encoding
import chardet
datos = open("/content/drive/MyDrive/Python/Pyratilla/characters-hp.csv","rb").read()
resultado = chardet.detect(datos)
encriptacion = resultado["encoding"]
encriptacion
# Out:
# 'Windows-1252'

# %%
import pandas as pd
hp_df = pd.read_csv("/content/drive/MyDrive/Python/Pyratilla/characters-hp.csv",sep = ";", encoding = "Windows-1252")

# %%
"""
Calcula el total de observaciones del csv que has guardado en la variable hp_df
"""
print("El total de observaciones es {}".format(hp_df.shape[0]))
# Out:
# El total de observaciones es 140

# %%
"""
Da la instrucción para visualizar las 10 primeras observaciones del dataframe
"""
hp_df.head(10)
# Out:
#    Id                                     Name  Gender  \
# 0   1                       Harry James Potter    Male
# 1   2                    Ronald Bilius Weasley    Male
# 2   3                    Hermione Jean Granger  Female
# 3   4  Albus Percival Wulfric Brian Dumbledore    Male
# 4   5                            Rubeus Hagrid    Male
# 5   6                       Neville Longbottom    Male
# 6   7                             Fred Weasley    Male
# 7   8                           George Weasley    Male
# 8   9            Ginevra (Ginny) Molly Weasley  Female
# 9  10                              Dean Thomas    Male
#
#                                                  Job       House  \
# 0                                            Student  Gryffindor
# 1                                            Student  Gryffindor
# 2                                            Student  Gryffindor
# 3                                         Headmaster  Gryffindor
# ...

# %%
"""
Averigua el índice de la columna llamada Id. 
Después, guarda en la variable hp_df todas las filas y 
todas las columnas salvo la columna que lleva por nombre Id. 
En otras palabras, 
elimina la columna que lleva por nombre Id del dataframe original haciendo uso del método .columns()
"""
for columna in hp_df.columns:
  print(columna)
# Out:
# Id
# Name
# Gender
# Job
# House
# Wand
# Patronus
# Species
# Blood status
# Hair colour
# Eye colour
# Loyalty
# Skills
# Birth
# Death

# %%
hp_df = hp_df[hp_df.columns[1:]]
for columna in hp_df.columns:
  print(columna)
# Out:
# Name
# Gender
# Job
# House
# Wand
# Patronus
# Species
# Blood status
# Hair colour
# Eye colour
# Loyalty
# Skills
# Birth
# Death

# %%
"""
Tras el cambio, ¿de cuántas variables consta el dataframe hp_df?
"""
print("El total de columnas es {}".format(hp_df.shape[1]))
# Out:
# El total de columnas es 14

# %%
"""
Di el valor de la variable Species para el personaje llamado Dobby 
sin usar el método .query()
"""
hp_df[hp_df["Name"] == "Dobby"]["Species"]
# Out:
# 138    House elf
# Name: Species, dtype: object

# %%
"""
Usa el método .query() para obtener únicamente las observaciones 
cuyo valor de la variable Job es Student 
guarda este dataframe filtrado en la variable hp_students
"""
hp_students = hp_df.query("Job == 'Student' ")
hp_students
# Out:
#                                          Name  Gender      Job       House  \
# 0                          Harry James Potter    Male  Student  Gryffindor
# 1                       Ronald Bilius Weasley    Male  Student  Gryffindor
# 2                       Hermione Jean Granger  Female  Student  Gryffindor
# 5                          Neville Longbottom    Male  Student  Gryffindor
# 6                                Fred Weasley    Male  Student  Gryffindor
# 7                              George Weasley    Male  Student  Gryffindor
# 8               Ginevra (Ginny) Molly Weasley  Female  Student  Gryffindor
# 9                                 Dean Thomas    Male  Student  Gryffindor
# 10                            Seamus Finnigan    Male  Student  Gryffindor
# 19                                Lee Jordan     Male  Student  Gryffindor
# 20                                Oliver Wood    Male  Student  Gryffindor
# ...

# %%
"""
Fíjate que los nombres de las filas del dataframe hp_students siguen siendo los originales.
Renombra las filas para que vayan del 1 al número total de observaciones que haya en hp_students. 
PISTA: Para acceder a los índices del dataframe puedes llamar al atributo index.
 Se trata de que sustituyas el original por una lista que contega como entradas 
 los números que van del 1 al número total de observaciones que tiene el dataframe hp_students
"""
hp_students.index=(list(range(1,hp_students.shape[0]+1)))
hp_students
# Out:
#                                         Name  Gender      Job       House  \
# 1                         Harry James Potter    Male  Student  Gryffindor
# 2                      Ronald Bilius Weasley    Male  Student  Gryffindor
# 3                      Hermione Jean Granger  Female  Student  Gryffindor
# 4                         Neville Longbottom    Male  Student  Gryffindor
# 5                               Fred Weasley    Male  Student  Gryffindor
# 6                             George Weasley    Male  Student  Gryffindor
# 7              Ginevra (Ginny) Molly Weasley  Female  Student  Gryffindor
# 8                                Dean Thomas    Male  Student  Gryffindor
# 9                            Seamus Finnigan    Male  Student  Gryffindor
# 10                               Lee Jordan     Male  Student  Gryffindor
# 11                               Oliver Wood    Male  Student  Gryffindor
# 12                          Angelina Johnson  Female  Student  Gryffindor
# ...

# %%
"""
¿Qué proporción de estudiantes hay?
 La proporción se calcula como el número de estudiantes 
 entre el número total de observaciones.
 """
print("¿Qué proporción de estudiantes hay? {}".format(hp_students.shape[0]/hp_df.shape[0]))
# Out:
# ¿Qué proporción de estudiantes hay? 0.37142857142857144

# %%
"""
¿Cuál es el valor de Hair colour para la observación 30 de hp_students? 
Calcúlalo usando el método .loc[]
"""
hp_students.loc[30,"Hair colour"]
# Out:
# 'Brown'

# %%
"""
Obtén la cantidad de colores diferentes 
que hay para la variable Eye colour en el dataframe hp_students. 
Recuerda que nan no es un color. 
¿Cuántos estudiantes no tienen un valor para la variable Eye colour?
"""
print(len(hp_students["Eye colour"].dropna().unique()))
print(hp_students[hp_students["Eye colour"].isnull()==True].shape[0])
# Out:
# 10
# 20

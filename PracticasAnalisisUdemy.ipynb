# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseNorbert/JoseNorbert/blob/main/PracticasAnalisisUdemy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Python/WordsByCharacter.csv")
multiindex = df.set_index(["Film","Chapter","Race","Character"]).sort_index()
multiindex
# Out:
#                                                                                                Words
# Film                       Chapter                                           Race   Character
# The Fellowship Of The Ring 01: Prologue                                      Elf    Elrond         5
#                                                                                     Galadriel    460
#                                                                              Gollum Gollum        20
#                                                                              Hobbit Bilbo          4
#                            02: Concerning Hobbits                            Hobbit Bilbo        214
# ...                                                                                              ...
# The Two Towers             65: The Battle For Middle Earth Is About To Begin Hobbit Sam           69
# ...

# %%
type(multiindex)
# Out:
# pandas.core.frame.DataFrame

# %%
multiindex.loc[('The Fellowship Of The Ring','01: Prologue'), :]
# Out:
#                   Words
# Race   Character
# Elf    Elrond         5
#        Galadriel    460
# Gollum Gollum        20
# Hobbit Bilbo          4
